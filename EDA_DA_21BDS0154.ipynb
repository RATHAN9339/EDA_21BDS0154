# %% [markdown]
# <a href="https://colab.research.google.com/github/RATHAN9339/EDA_21BDS0154/blob/main/EDA_DA_21BDS0154.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# Import Dataset

# %%
df=pd.read_csv("elem94_95.csv")
df.index=df['rownames']
df.drop('rownames',axis=1,inplace=True)

# %%
df.head()
# Out:
#           distid  schid      lunch  enrol       staff  exppp  avgsal  avgben  \
# rownames
# 1           1010   4937  48.299999    539   71.099998   3586   39383   13656
# 2           2010   4959  51.500000     59  127.099998   4357   25622   10004
# 3           2020   4999  51.200001     82  122.599998   5667   31318   12645
# 4           2070    597  33.700001    409   77.500000   2752   27873    9657
# 5           3010    790  11.900000    259   87.599998   3253   31264   10017
#
#               math4     story4        bs    lavgsal    lenrol    lstaff
# rownames
# 1         68.000000  70.699997  0.346749  10.581090  6.289716  4.264087
# 2         40.000000  40.000000  0.390446  10.151207  4.077538  4.844974
# 3         57.099998  57.099998  0.403761  10.351949  4.406719  4.808927
# 4         63.200001  73.500000  0.346464  10.235414  6.013715  4.350278
# 5         56.400002  64.099998  0.320400  10.350223  5.556828  4.472781

# %%
df.tail()
# Out:
#           distid  schid      lunch  enrol      staff  exppp  avgsal  avgben  \
# rownames
# 1844       83010   2210  62.799999    303  64.199997   3049   37658   12231
# 1845       83010   2480  50.000000    281  65.500000   2997   33885   11884
# 1846       83010   5101  41.000000    281  64.800003   2983   36244   12120
# 1847       83060   5901   0.000000    506  76.599998   3302   31165   11462
# 1848       83070   2527   0.000000    528  58.700001   2482   30549   10685
#
#               math4     story4        bs    lavgsal    lenrol    lstaff
# rownames
# 1844      52.000000  58.000000  0.324792  10.536301  5.713733  4.162003
# 1845      49.000000  74.500000  0.350716  10.430728  5.638355  4.182050
# 1846      70.400002  77.800003  0.334400  10.498029  5.638355  4.171306
# 1847      53.400002  66.099998  0.367784  10.347051  6.226537  4.338597
# 1848      43.900002  62.099998  0.349766  10.327087  6.269096  4.072440

# %%
df.sample(5)
# Out:
#           distid  schid      lunch  enrol       staff  exppp  avgsal  avgben  \
# rownames
# 1091       63080   5766   1.200000    326  118.900002   5520   41589   12467
# 1748       82120    970  66.699997    499   80.400002   3924   38871   13836
# 425        33020   1269  40.900002    368   62.500000   3648   47720   17502
# 807        50160     49  59.299999    484   62.400002   4141   48762   17547
# 667        41160   3556  35.700001    409   78.699997   2892   28494    9074
#
#               math4     story4        bs    lavgsal    lenrol    lstaff
# rownames
# 1091      88.000000  92.000000  0.299767  10.635591  5.786897  4.778283
# 1748      40.799999  46.900002  0.355947  10.568004  6.212606  4.387014
# 425       57.799999  70.300003  0.366764  10.773106  5.908083  4.135167
# 807       49.099998  78.199997  0.359850  10.794706  6.182085  4.133565
# 667       83.699997  71.400002  0.318453  10.257449  6.013715  4.365643

# %% [markdown]
# Data Handling

# %%
print("Dimensions:",df.shape)
# Out:
# Dimensions: (1848, 14)

# %%
print("Data Info:",df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1848 entries, 1 to 1848
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   distid   1848 non-null   int64
#  1   schid    1848 non-null   int64
#  2   lunch    1848 non-null   float64
#  3   enrol    1848 non-null   int64
#  4   staff    1848 non-null   float64
#  5   exppp    1848 non-null   int64
#  6   avgsal   1848 non-null   int64
#  7   avgben   1848 non-null   int64
#  8   math4    1848 non-null   float64
#  9   story4   1848 non-null   float64
#  10  bs       1848 non-null   float64
#  11  lavgsal  1848 non-null   float64
#  12  lenrol   1848 non-null   float64
#  13  lstaff   1848 non-null   float64
# dtypes: float64(8), int64(6)
# memory usage: 216.6 KB
# Data Info: None

# %%
print("Summary Statistics:",df.describe(include='all'))
# Out:
# Summary Statistics:              distid        schid        lunch        enrol        staff  \
# count   1848.000000  1848.000000  1848.000000  1848.000000  1848.000000
# mean   52808.780844  3016.323052    36.338312   413.372294    77.270725
# std    23888.658243  2078.361091    25.358307   164.094988    20.133451
# min     1010.000000     1.000000     0.000000    11.000000    33.799999
# 25%    33130.000000  1293.750000    15.375000   304.000000    65.199997
# 50%    56010.000000  2589.500000    32.300001   404.500000    74.300003
# 75%    75052.500000  4472.750000    53.325000   505.000000    85.000000
# max    83070.000000  8056.000000   100.000000  1177.000000   343.799988
#
#              exppp        avgsal        avgben        math4       story4  \
# count  1848.000000   1848.000000   1848.000000  1848.000000  1848.000000
# mean   3401.695346  36367.975649  12459.902056    61.418831    70.234632
# std     598.104806   8369.190353   3054.908506    18.850803    14.638224
# min    1353.000000   9297.000000   3295.000000     7.100000    18.799999
# 25%    3014.000000  30616.000000  10440.750000    49.875000    61.400002
# 50%    3311.500000  35699.500000  12079.000000    62.900002    71.900002
# 75%    3664.000000  41077.000000  14026.000000    75.000000    80.800003
# max    7014.000000  73200.000000  30731.000000   100.000000   100.000000
#
#                 bs      lavgsal       lenrol       lstaff
# count  1848.000000  1848.000000  1848.000000  1848.000000
# mean      0.343334    10.474903     5.931112     4.319726
# std       0.035947     0.232895     0.478038     0.227894
# min       0.097215     9.137447     2.397895     3.520461
# 25%       0.324997    10.329278     5.717028     4.177459
# 50%       0.338656    10.482892     6.002651     4.308111
# 75%       0.358503    10.623204     6.224558     4.442651
# max       0.999785    11.200951     7.070724     5.840060

# %% [markdown]
# Data Cleaning

# %%
print("Missing Values per Column:")
print(df.isnull().sum())
# Out:
# Missing Values per Column:
# distid     0
# schid      0
# lunch      0
# enrol      0
# staff      0
# exppp      0
# avgsal     0
# avgben     0
# math4      0
# story4     0
# bs         0
# lavgsal    0
# lenrol     0
# lstaff     0
# dtype: int64

# %%
print("Duplicate Rows:", df.duplicated().sum())
# Out:
# Duplicate Rows: 0

# %%
#Outlier Dectection
for column in df.select_dtypes(include=np.number).columns:
    plt.figure(figsize=(6, 3))
    sns.boxplot(df[column])
    plt.title(f"Boxplot of {column}")
    plt.show()

# %% [markdown]
# Univariate Analysis

# %%
for column in df.select_dtypes(include=np.number).columns:
    plt.figure(figsize=(8, 4))
    sns.histplot(df[column], kde=True)
    plt.title(f"Distribution of {column}")
    plt.show()

# %% [markdown]
# Bivariate Analysis

# %%
#Heat Map
cor=df.corr()
plt.figure(figsize=(10, 6))
sns.heatmap(cor, annot=True, cmap='PiYG')
plt.title("Correlation Heatmap")
plt.show()
